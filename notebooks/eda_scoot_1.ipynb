# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
database_name = 'scoots'

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
engine = create_engine(connection_string)

# %% [markdown]
# ### EDA

# %%
schema_scooters = '''
SELECT *
FROM INFORMATION_SCHEMA.COLUMNS
WHERE TABLE_NAME = 'scooters'
ORDER BY ORDINAL_POSITION
'''

sch_scoo = pd.read_sql(schema_scooters, con = engine)
sch_scoo
# Out:
#   table_catalog table_schema table_name  column_name  ordinal_position
# 0        scoots       public   scooters  pubdatetime                 1  \
# 1        scoots       public   scooters     latitude                 2
# 2        scoots       public   scooters    longitude                 3
# 3        scoots       public   scooters       sumdid                 4
# 4        scoots       public   scooters     sumdtype                 5
# 5        scoots       public   scooters  chargelevel                 6
# 6        scoots       public   scooters    sumdgroup                 7
# 7        scoots       public   scooters   costpermin                 8
# 8        scoots       public   scooters  companyname                 9
#
#   column_default is_nullable                    data_type
# 0           None         YES  timestamp without time zone  \
# 1           None         YES                      numeric
# 2           None         YES                      numeric
# 3           None         YES                         text
# 4           None         YES                         text
# 5           None         YES                      numeric
# 6           None         YES                         text
# 7           None         YES                      numeric
# 8           None         YES                         text
#
#   character_maximum_length  character_octet_length  ... is_identity
# 0                     None                     NaN  ...          NO  \
# 1                     None                     NaN  ...          NO
# 2                     None                     NaN  ...          NO
# 3                     None            1.073742e+09  ...          NO
# 4                     None            1.073742e+09  ...          NO
# 5                     None                     NaN  ...          NO
# 6                     None            1.073742e+09  ...          NO
# 7                     None                     NaN  ...          NO
# 8                     None            1.073742e+09  ...          NO
#
#    identity_generation identity_start  identity_increment identity_maximum
# 0                 None           None                None             None  \
# 1                 None           None                None             None
# 2                 None           None                None             None
# 3                 None           None                None             None
# 4                 None           None                None             None
# 5                 None           None                None             None
# 6                 None           None                None             None
# 7                 None           None                None             None
# 8                 None           None                None             None
#
#   identity_minimum identity_cycle is_generated generation_expression
# 0             None             NO        NEVER                  None  \
# 1             None             NO        NEVER                  None
# 2             None             NO        NEVER                  None
# 3             None             NO        NEVER                  None
# 4             None             NO        NEVER                  None
# 5             None             NO        NEVER                  None
# 6             None             NO        NEVER                  None
# 7             None             NO        NEVER                  None
# 8             None             NO        NEVER                  None
#
#   is_updatable
# 0          YES
# 1          YES
# 2          YES
# 3          YES
# 4          YES
# 5          YES
# 6          YES
# 7          YES
# 8          YES
#
# [9 rows x 44 columns]

# %%
schema_trips = '''
SELECT *
FROM INFORMATION_SCHEMA.COLUMNS
WHERE TABLE_NAME = 'trips'
ORDER BY ORDINAL_POSITION
'''

sch_tri = pd.read_sql(schema_trips, con = engine)
sch_tri
# Out:
#    table_catalog table_schema table_name     column_name  ordinal_position
# 0         scoots       public      trips    pubtimestamp                 1  \
# 1         scoots       public      trips     companyname                 2
# 2         scoots       public      trips   triprecordnum                 3
# 3         scoots       public      trips          sumdid                 4
# 4         scoots       public      trips    tripduration                 5
# 5         scoots       public      trips    tripdistance                 6
# 6         scoots       public      trips       startdate                 7
# 7         scoots       public      trips       starttime                 8
# 8         scoots       public      trips         enddate                 9
# 9         scoots       public      trips         endtime                10
# 10        scoots       public      trips   startlatitude                11
# 11        scoots       public      trips  startlongitude                12
# 12        scoots       public      trips     endlatitude                13
# 13        scoots       public      trips    endlongitude                14
# 14        scoots       public      trips       triproute                15
# 15        scoots       public      trips       create_dt                16
#
#    column_default is_nullable                    data_type
# 0            None         YES  timestamp without time zone  \
# 1            None         YES                         text
# 2            None         YES                         text
# 3            None         YES                         text
# 4            None         YES                      numeric
# 5            None         YES                      numeric
# 6            None         YES                         date
# 7            None         YES       time without time zone
# 8            None         YES                         date
# 9            None         YES       time without time zone
# 10           None         YES                      numeric
# 11           None         YES                      numeric
# 12           None         YES                      numeric
# 13           None         YES                      numeric
# 14           None         YES                         text
# 15           None         YES  timestamp without time zone
#
#    character_maximum_length  character_octet_length  ... is_identity
# 0                      None                     NaN  ...          NO  \
# 1                      None            1.073742e+09  ...          NO
# 2                      None            1.073742e+09  ...          NO
# 3                      None            1.073742e+09  ...          NO
# 4                      None                     NaN  ...          NO
# 5                      None                     NaN  ...          NO
# 6                      None                     NaN  ...          NO
# 7                      None                     NaN  ...          NO
# 8                      None                     NaN  ...          NO
# 9                      None                     NaN  ...          NO
# 10                     None                     NaN  ...          NO
# 11                     None                     NaN  ...          NO
# 12                     None                     NaN  ...          NO
# 13                     None                     NaN  ...          NO
# 14                     None            1.073742e+09  ...          NO
# 15                     None                     NaN  ...          NO
#
#     identity_generation identity_start  identity_increment identity_maximum
# 0                  None           None                None             None  \
# 1                  None           None                None             None
# 2                  None           None                None             None
# 3                  None           None                None             None
# 4                  None           None                None             None
# 5                  None           None                None             None
# 6                  None           None                None             None
# 7                  None           None                None             None
# 8                  None           None                None             None
# 9                  None           None                None             None
# 10                 None           None                None             None
# 11                 None           None                None             None
# 12                 None           None                None             None
# 13                 None           None                None             None
# 14                 None           None                None             None
# 15                 None           None                None             None
#
#    identity_minimum identity_cycle is_generated generation_expression
# 0              None             NO        NEVER                  None  \
# 1              None             NO        NEVER                  None
# 2              None             NO        NEVER                  None
# 3              None             NO        NEVER                  None
# 4              None             NO        NEVER                  None
# 5              None             NO        NEVER                  None
# 6              None             NO        NEVER                  None
# 7              None             NO        NEVER                  None
# 8              None             NO        NEVER                  None
# 9              None             NO        NEVER                  None
# 10             None             NO        NEVER                  None
# 11             None             NO        NEVER                  None
# 12             None             NO        NEVER                  None
# 13             None             NO        NEVER                  None
# 14             None             NO        NEVER                  None
# 15             None             NO        NEVER                  None
#
#    is_updatable
# 0           YES
# 1           YES
# 2           YES
# 3           YES
# 4           YES
# 5           YES
# 6           YES
# 7           YES
# 8           YES
# 9           YES
# 10          YES
# 11          YES
# 12          YES
# 13          YES
# 14          YES
# 15          YES
#
# [16 rows x 44 columns]

# %% [markdown]
#     - Are there any null values in any columns in either table?

# %%
deez_nulls = '''
SELECT 
    SUM (CASE when chargelevel ISNULL then 1 else 0 end)/SUM(1.0)
FROM scooters
'''

dn1 = pd.read_sql(deez_nulls, con = engine)
dn1
# Out:
#    ?column?
# 0   0.00001

# %%
deez_nulls2 = '''
SELECT 
    SUM (CASE when create_dt ISNULL then 1 else 0 end)/SUM(1.0)
FROM trips
'''

dn2 = pd.read_sql(deez_nulls2, con = engine)
dn2
# Out:
#    ?column?
# 0       0.0

# %% [markdown]
#     - What date range is represented in each of the date columns? Investigate any values that seem odd.
# (trips is pubtimestamp)

# %%
date_scoo = '''
SELECT 
    MAX(pubdatetime),
    MIN(pubdatetime)
FROM scooters
'''

ds = pd.read_sql(date_scoo, con=engine)
ds
# Out:
#                   max                     min
# 0 2019-07-31 23:59:57 2019-05-01 00:01:41.247

# %%
date_trips = '''
SELECT 
    MAX(pubtimestamp),
    MIN(pubtimestamp)
FROM trips
'''

dt = pd.read_sql(date_trips, con=engine)
dt
# Out:
#                   max                     min
# 0 2019-08-01 07:04:00 2019-05-01 00:00:55.423

# %%
overtime = '''
SELECT *
FROM trips
WHERE pubtimestamp = '2019-08-01 07:04:00'
'''

ot = pd.read_sql(overtime, con=engine)
ot
# Out:
#          pubtimestamp companyname triprecordnum
# 0 2019-08-01 07:04:00        JUMP         JMP35  \
# 1 2019-08-01 07:04:00        JUMP         JMP34
#
#                                         sumdid  tripduration  tripdistance
# 0  Poweredf077a919-d569-5e70-8ca7-71d179ffacf9     142.34561       20433.6  \
# 1  Powered784fcc92-bd1a-5f6a-8314-b02aa21b4bfa     209.40965       14889.6
#
#     startdate starttime     enddate   endtime  startlatitude  startlongitude
# 0  2019-07-31  23:26:15  2019-08-01  01:48:35      36.155735      -86.775185  \
# 1  2019-07-31  22:19:08  2019-08-01  01:48:33      36.160050      -86.776720
#
#    endlatitude  endlongitude
# 0    36.173904     -86.78545  \
# 1    36.163410     -86.78210
#
#                                            triproute               create_dt
# 0  [('36.155736', '-86.775181'), ('36.155531', '-... 2019-08-02 08:24:21.967
# 1  [('36.160051', '-86.77672'), ('36.160051', '-8... 2019-08-02 08:24:22.000

# %%
overtime2 = '''
SELECT *
FROM trips
WHERE pubtimestamp = '2019-08-01 07:04:00'
'''

ot2 = pd.read_sql(overtime, con=engine)
ot2
# Out:
#          pubtimestamp companyname triprecordnum
# 0 2019-08-01 07:04:00        JUMP         JMP35  \
# 1 2019-08-01 07:04:00        JUMP         JMP34
#
#                                         sumdid  tripduration  tripdistance
# 0  Poweredf077a919-d569-5e70-8ca7-71d179ffacf9     142.34561       20433.6  \
# 1  Powered784fcc92-bd1a-5f6a-8314-b02aa21b4bfa     209.40965       14889.6
#
#     startdate starttime     enddate   endtime  startlatitude  startlongitude
# 0  2019-07-31  23:26:15  2019-08-01  01:48:35      36.155735      -86.775185  \
# 1  2019-07-31  22:19:08  2019-08-01  01:48:33      36.160050      -86.776720
#
#    endlatitude  endlongitude
# 0    36.173904     -86.78545  \
# 1    36.163410     -86.78210
#
#                                            triproute               create_dt
# 0  [('36.155736', '-86.775181'), ('36.155531', '-... 2019-08-02 08:24:21.967
# 1  [('36.160051', '-86.77672'), ('36.160051', '-8... 2019-08-02 08:24:22.000

# %%
count = '''SELECT COUNT(pubtimestamp) FROM trips'''
cou = pd.read_sql(count, con=engine)
cou
# Out:
#     count
# 0  565522

# %% [markdown]
# ### crash and crash2 are ordered by timestamp in desc and asc order

# %%
crash = '''
SELECT * 
FROM trips 
ORDER BY pubtimestamp DESC 
LIMIT 10
'''

cra = pd.read_sql(crash, con=engine)
cra
# Out:
#              pubtimestamp companyname triprecordnum
# 0 2019-08-01 07:04:00.000        JUMP         JMP34  \
# 1 2019-08-01 07:04:00.000        JUMP         JMP35
# 2 2019-08-01 04:53:48.000        JUMP          JMP1
# 3 2019-08-01 04:53:48.000        JUMP          JMP4
# 4 2019-08-01 04:53:48.000        JUMP          JMP3
# 5 2019-08-01 04:53:48.000        JUMP          JMP2
# 6 2019-08-01 04:53:48.000        JUMP          JMP6
# 7 2019-08-01 02:14:12.163        SPIN        SPI201
# 8 2019-08-01 01:04:46.710        Lyft        LFT106
# 9 2019-08-01 00:59:26.157        Lime     LIM824111
#
#                                         sumdid  tripduration  tripdistance
# 0  Powered784fcc92-bd1a-5f6a-8314-b02aa21b4bfa    209.409650  14889.600000  \
# 1  Poweredf077a919-d569-5e70-8ca7-71d179ffacf9    142.345610  20433.600000
# 2  Poweredb8a3a269-d1ca-571f-9b2f-89b7399b5537     18.440650   7920.000000
# 3  Powered1691872e-b176-5fc6-86ed-967d00644179     17.567150   7497.600000
# 4  Powered5614e4fc-1971-5e5c-a545-0fd88cd3331d     17.497950   7075.200000
# 5  Powereda4712099-5e55-5332-996c-d6e5c910535d      3.154917   1320.000000
# 6  Poweredd913663d-659b-5afd-9a37-a1b85c6a36b2     11.364550   5808.000000
# 7                               Powered6219542    140.000000    239.501320
# 8                                Powered786553     69.087417  28139.764680
# 9                         Powered7C527S3HH24NS     24.000000  12876.353853
#
#     startdate        starttime     enddate          endtime  startlatitude
# 0  2019-07-31         22:19:08  2019-08-01         01:48:33      36.160050  \
# 1  2019-07-31         23:26:15  2019-08-01         01:48:35      36.155735
# 2  2019-07-31         23:41:52  2019-08-01         00:00:18      36.153687
# 3  2019-07-31         23:47:56  2019-08-01         00:05:30      36.154640
# 4  2019-07-31         23:47:43  2019-08-01         00:05:13      36.154633
# 5  2019-07-31         23:57:19  2019-08-01         00:00:28      36.153015
# 6  2019-07-31         23:57:37  2019-08-01         00:08:59      36.150910
# 7  2019-07-31         23:54:20  2019-08-01         02:14:09      36.148476
# 8  2019-07-31  23:55:41.390000  2019-08-01  01:04:46.633333      36.164780
# 9  2019-07-31         23:57:38  2019-08-01         00:21:42      36.189432
#
#    startlongitude  endlatitude  endlongitude
# 0      -86.776720    36.163410    -86.782100  \
# 1      -86.775185    36.173904    -86.785450
# 2      -86.784580    36.164158    -86.776900
# 3      -86.798420    36.149390    -86.814156
# 4      -86.798340    36.149220    -86.813980
# 5      -86.783585    36.152843    -86.779594
# 6      -86.782810    36.159283    -86.777880
# 7      -86.807011    36.147899    -86.807403
# 8      -86.779850    36.214170    -86.758240
# 9      -86.801973    36.188100    -86.800985
#
#                                            triproute               create_dt
# 0  [('36.160051', '-86.77672'), ('36.160051', '-8... 2019-08-02 08:24:22.000
# 1  [('36.155736', '-86.775181'), ('36.155531', '-... 2019-08-02 08:24:21.967
# 7  00:10:50.116666       36.15193       -86.78439     36.15463     -86.78492
# 8  00:12:48.676666       36.17080       -86.78930     36.17460     -86.78600
# 9  00:11:19.183333       36.15650       -86.79710     36.15120     -86.79680
#
#                                            triproute               create_dt
# 0  [(36.157235, -86.803612), (36.157235, -86.8036... 2019-05-02 05:30:23.780
# 1  [(36.15797, -86.77896), (36.15795, -86.77873),... 2019-05-02 07:20:32.757
# 2  [(36.177699, -86.786477), (36.177711, -86.7864... 2019-05-02 05:30:24.207
# 3  [(36.154368, -86.785909), (36.151689, -86.7843... 2019-05-02 05:30:24.317
# 4  [(36.155068, -86.782124), (36.156597, -86.78675)] 2019-05-02 05:30:24.530
# 5  [(36.149741, -86.779344), (36.149741, -86.7793... 2019-05-02 05:30:24.237
# 6     [(36.15168, -86.78408), (36.15171, -86.78411)] 2019-05-02 07:20:32.890
# 7  [(36.15193, -86.78439), (36.15188, -86.78432),... 2019-05-02 07:20:32.990
# 8  [(36.170995, -86.789593), (36.173193, -86.7912... 2019-05-02 05:30:24.833
# 9  [(36.15654, -86.797137), (36.153065, -86.79804... 2019-05-02 05:30:24.920

# %% [markdown]
# trips for scooter Powered9EAJL

# %%
crash3 = '''
SELECT * 
FROM trips 
WHERE sumdid = 'Powered9EAJL'
'''

cra3 = pd.read_sql(crash3, con=engine)
cra3
# Out:
#              pubtimestamp companyname triprecordnum        sumdid
# 0 2019-05-01 00:00:55.423        Bird       BRD2134  Powered9EAJL  \
# 1 2019-05-02 03:37:11.417        Bird       BRD2352  Powered9EAJL
# 2 2019-05-03 19:09:06.420        Bird       BRD1534  Powered9EAJL
# 3 2019-05-07 18:03:49.303        Bird        BRD789  Powered9EAJL
#
#    tripduration  tripdistance   startdate        starttime     enddate
# 0           3.0     958.00528  2019-05-01  00:00:20.460000  2019-05-01  \
# 1           7.0    4488.18912  2019-05-02  03:30:18.376666  2019-05-02
# 2          15.0    7500.00024  2019-05-03  18:54:18.040000  2019-05-03
# 3           3.0     777.55908  2019-05-07  18:02:51.126666  2019-05-07
#
#            endtime  startlatitude  startlongitude  endlatitude  endlongitude
# 0  00:02:52.346666        36.1571        -86.8036      36.1566      -86.8067  \
# 1  03:37:47.066666        36.1507        -86.7968      36.1492      -86.8070
# 2  19:09:19.356666        36.1563        -86.7750      36.1649      -86.7734
# 3  18:05:34.500000        36.1712        -86.7521      36.1712      -86.7524
#
#                                            triproute               create_dt
# 0  [(36.157235, -86.803612), (36.157235, -86.8036... 2019-05-02 05:30:23.780
# 1  [(36.150866, -86.796952), (36.150866, -86.7969... 2019-05-03 05:30:31.620
# 2  [(36.156886, -86.775284), (36.156886, -86.7752... 2019-05-04 05:31:20.147
# 3  [(36.17125, -86.752052), (36.17125, -86.752052... 2019-05-08 05:31:14.120

# %% [markdown]
# trips per scooter id

# %%
crash4 = ''' 
SELECT 
    DISTINCT sumdid,
    COUNT (sumdid)
FROM trips
GROUP BY sumdid
ORDER BY COUNT(sumdid) DESC
LIMIT 5
'''

cra4 = pd.read_sql(crash4, con=engine)
cra4
# Out:
#                                         sumdid  count
# 0                               PoweredUNKNOWN   3613
# 1  Poweredb671ffe4-2bca-5880-98ec-d36f65aa11a2   1908
# 2                         PoweredR3QXO6TL2HIAB    382
# 3                         PoweredZ6HF5P5HCJCT5    369
# 4                         PoweredCL37MXJKM7RS5    352

# %% [markdown]
# PoweredUNKOWN?

# %%
crash5 = '''
SELECT DISTINCT sumdid
FROM scooters
WHERE sumdid NOT IN
    (SELECT 
        DISTINCT sumdid
    FROM trips
    WHERE sumdid != 'PoweredUNKOWN' 
    GROUP BY sumdid)
AND sumdid LIKE '%%Powered%%'
'''

cra5 = pd.read_sql(crash5, con=engine)
cra5
# Out:
#                                             sumdid
# 0     Powered-720e0c75-ae20-7c02-df74-278a87969ccb
# 1     Powered-89cac6cd-4377-a2ad-68ff-645c32ae51c6
# 2     Powered-f9bee790-0731-15a4-0890-7772ceb14397
# 3     Powered-ff728c28-5239-68af-ddf3-6d1207b01196
# 4      Powered00746183-96c8-58d7-97b5-04a091c91b34
# ...                                            ...
# 1053                                  PoweredYY392
# 1054                                  PoweredZ8GTQ
# 1055                          PoweredZE4UL6WZCANAB
# 1056                          PoweredZWYUH3I4RHH3I
# 1057                                  PoweredZZ1Q6
#
# [1058 rows x 1 columns]

# %%
crash6 = '''
SELECT 
    DISTINCT sumdid,
    latitude,
    longitude
FROM scooters
WHERE sumdid NOT IN
    (SELECT 
        DISTINCT sumdid
    FROM trips
    WHERE sumdid != 'PoweredUNKOWN' 
    GROUP BY sumdid)
AND sumdid LIKE '%%Powered%%'
'''

cra6 = pd.read_sql(crash6, con=engine)
cra6
# Out:
#                                              sumdid   latitude  longitude
# 0                              PoweredA54P7DOFZA7I2  36.157653 -86.745701
# 1                              PoweredIE7H5RIN474PE  36.149986 -86.761914
# 2                                        Powered482  36.121424 -86.770417
# 3       Powered55134b7a-6fbc-57f6-affd-5682f732c068  36.156200 -86.775500
# 4       Poweredb5e5f524-99e1-5037-b35b-e10c220c6984  36.120300 -86.753400
# ...                                             ...        ...        ...
# 177787  Powered80c50ab2-27a4-5dda-82f4-0a01dd3afcdf  36.143300 -86.792600
# 177788  Poweredb7f0b347-68d4-54cb-baa8-82d53a72f9ca  36.120700 -86.753500
# 177789  Poweredf0e72326-77bb-5609-b550-f619a28e58f0  36.159000 -86.776000
# 177790  Powered0eaa1adb-095f-5078-995a-c0364432d88a  36.157000 -86.794400
# 177791  Powered327cb256-dcaa-59f2-bed3-d4cdfeb52bc1  36.120000 -86.753500
#
# [177792 rows x 3 columns]

# %% [markdown]
# scooters per company(clearly incorrect)

# %%
uni_com = '''
SELECT 
    DISTINCT companyname,
    COUNT (companyname)
FROM scooters
GROUP BY companyname
ORDER BY COUNT(companyname) DESC
'''

uc = pd.read_sql(uni_com, con=engine)
uc
# Out:
#   companyname     count
# 0        Jump  21835098
# 1        Lime  16524261
# 2        Bird  12251590
# 3        Lyft   9087043
# 4        Spin   5559573
# 5      Gotcha   4679280
# 6        Bolt   3477198

# %% [markdown]
# V unique scooters V

# %%
uni_scoo = '''
SELECT 
    DISTINCT sumdid,
    COUNT(sumdid)
FROM scooters
GROUP BY sumdid
ORDER BY COUNT(sumdid) DESC
'''

us = pd.read_sql(uni_scoo, con=engine)
us
# Out:
#                       sumdid  count
# 0      StandardNW5HJFO4R32LY  26476
# 1       PoweredCPBMGOVZOHE4Z  25279
# 2       PoweredUNORTWSTRM4AM  24839
# 3                 Powered253  22748
# 4                 Powered341  22748
# ...                      ...    ...
# 10013   PoweredMMQC4MGMOH675      1
# 10014   PoweredN4YI2A7RXZQLY      1
# 10015   PoweredUKDFR5O5HBMBO      1
# 10016           PoweredXCPDB      1
# 10017           PoweredYEBSU      1
#
# [10018 rows x 2 columns]

# %% [markdown]
# ### Fewer than 5 observations from scooters

# %%
maiden = '''
SELECT DISTINCT sumdid
FROM scooters
GROUP BY sumdid
HAVING COUNT(sumdid) <= 5 
'''

ninja_maiden = pd.read_sql(maiden, con=engine)
ninja_maiden
# Out:
#                                           sumdid
# 0   Powered-720e0c75-ae20-7c02-df74-278a87969ccb
# 1   Powered-ff728c28-5239-68af-ddf3-6d1207b01196
# 2                                  Powered047010
# 3                                   Powered1PKP7
# 4                                   Powered28NX9
# 5                                   Powered2WZD8
# 6                                   Powered3PD13
# 7                                   Powered3ZPZ7
# 8                                 Powered4314410
# 9                                   Powered4AP86
# 10                                  Powered4E63K
# 11                                 Powered587699
# 12                                  Powered5WF3M
# 13                                Powered6599831
# 14                                Powered6668448
# 15                          Powered6EPAKQB4QHWJF
# 16                          Powered6TPOZJO4U6WGE
# 17                                  Powered71BQW
# 18                                Powered8019965
# 19                                  Powered9EEIU
# 20                                  PoweredA93MU
# 21                                  PoweredA9GT8
# 22                          PoweredBHQPF4NGORWCW
# 23                          PoweredC7EZRZTYAREOS
# 24                          PoweredCI6VKIK2KOFMC
# 25                          PoweredCU5ZHYOO2ST5J
# 26                                  PoweredCV6AA
# 27                          PoweredCW742BQMJ3XHN
# 28                          PoweredEDK4WGEINP4BT
# 29                                   PoweredEIVB
# 30                          PoweredFDPBKXIAIXBW2
# 31                          PoweredGJYGPDVTFXRH7
# 32                                  PoweredI946K
# 33                          PoweredIF7UIJXEPYHJU
# 34                                  PoweredIW4P9
# 35                          PoweredMMQC4MGMOH675
# 36                          PoweredN4YI2A7RXZQLY
# 37                                  PoweredPGT79
# 38                          PoweredPH4ZZXMP4COWC
# 39                          PoweredPHTH7E5R7AWOA
# 40                          PoweredQCNFR2SCRC6BZ
# 41                                  PoweredRXTDE
# 42                                  PoweredSZPVJ
# 43                          PoweredUKDFR5O5HBMBO
# 44                                  PoweredXCPDB
# 45                                  PoweredYEBSU
# 46                          PoweredZWYUH3I4RHH3I

# %%
maiden2 = '''
SELECT 
    COUNT(DISTINCT sumdid),
    companyname
FROM scooters
WHERE sumdid IN 
    (SELECT DISTINCT sumdid
    FROM scooters
    GROUP BY sumdid
    HAVING COUNT(sumdid) <= 5)
GROUP BY companyname
'''

ninja_maiden2 = pd.read_sql(maiden2, con=engine)
ninja_maiden2
# Out:
#    count companyname
# 0     21        Bird
# 1      2        Bolt
# 2     18        Lime
# 3      2        Lyft
# 4      4        Spin

# %%
maiden3 = '''
SELECT *
FROM scooters
WHERE sumdid IN 
    (SELECT DISTINCT sumdid
    FROM scooters
    GROUP BY sumdid
    HAVING COUNT(sumdid) <= 5)
ORDER BY pubdatetime
'''

ninja_maiden3 = pd.read_sql(maiden3, con=engine)
ninja_maiden3
# Out:
#                pubdatetime   latitude  longitude        sumdid sumdtype
# 0  2019-05-01 00:01:41.247  36.161052 -86.781899  PoweredYEBSU  Powered  \
# 1  2019-05-01 01:51:45.540  36.161701 -86.776124  PoweredIW4P9  Powered
# 2  2019-05-01 03:01:48.277  36.162040 -86.776115  PoweredIW4P9  Powered
# 3  2019-05-01 14:22:15.107  36.144275 -86.806275  PoweredCV6AA  Powered
# 4  2019-05-01 14:27:15.290  36.146168 -86.804145  PoweredCV6AA  Powered
# ..                     ...        ...        ...           ...      ...
# 90 2019-07-27 01:44:57.050  36.184003 -86.748124  Powered3PD13  Powered
# 91 2019-07-27 01:49:57.057  36.184043 -86.748175  Powered3PD13  Powered
# 92 2019-07-27 17:05:23.127  36.158738 -86.768364  PoweredA9GT8  Powered
# 93 2019-07-29 16:31:47.630  36.158474 -86.768241  Powered3ZPZ7  Powered
# 94 2019-07-31 21:18:13.167  36.073140 -86.797854  Powered5WF3M  Powered
#
#     chargelevel sumdgroup  costpermin companyname
# 0          73.0   scooter        0.00        Bird
# 1          26.0   scooter        0.00        Bird
# 2          20.0   scooter        0.00        Bird
# 3          86.0   scooter        0.00        Bird
# 4          86.0   scooter        0.00        Bird
# ..          ...       ...         ...         ...
# 90         56.0   scooter        0.15        Bird
# 91         56.0   scooter        0.15        Bird
# 92         99.0   scooter        0.15        Bird
# 93         23.0   scooter        0.15        Bird
# 94         77.0   scooter        0.15        Bird
#
# [95 rows x 9 columns]

# %% [markdown]
#     - Is time represented with am/pm or using 24 hour values in each of the columns that include time?

# %%
time = '''
SELECT 
    MAX(s.pubdatetime) as scooter_date,
    (SELECT MAX(pubtimestamp) FROM trips) as trip_date,
    (SELECT MAX(starttime) FROM trips) as trip_start,
    (SELECT MAX(endtime) FROM trips) as trip_end,
    (SELECT MAX(create_dt) FROM trips) as trip_dt
FROM scooters as s
'''

t = pd.read_sql(time, con=engine)
t
# Out:
#          scooter_date           trip_date       trip_start         trip_end
# 0 2019-07-31 23:59:57 2019-08-01 07:04:00  23:59:59.506666  23:59:59.310000  \
#
#                   trip_dt
# 0 2019-08-02 11:30:29.923

# %% [markdown]
# could refer back to crash 3 for pubtimestamp

# %%
time2 = '''
SELECT *
FROM trips
WHERE sumdid = 'PoweredCL37MXJKM7RS5'
LIMIT 10	
'''

t2 = pd.read_sql(time2, con=engine)
t2
# Out:
#              pubtimestamp companyname triprecordnum                sumdid
# 0 2019-07-06 16:55:43.923        Lime     LIM791853  PoweredCL37MXJKM7RS5  \
# 1 2019-07-06 17:55:46.430        Lime     LIM792075  PoweredCL37MXJKM7RS5
# 2 2019-07-06 18:55:45.873        Lime     LIM792186  PoweredCL37MXJKM7RS5
stdunk = '''
SELECT COUNT(*)
FROM trips
WHERE sumdid = 'PoweredUNKNOWN'
'''

sd = pd.read_sql(stdunk, con=engine)
sd
# Out:
#    count
# 0   3613

# %%
chle = '''
SELECT 
    DISTINCT chargelevel,
    COUNT (chargelevel)
FROM scooters
GROUP BY chargelevel
'''

cl = pd.read_sql(chle, con=engine)
cl
# Out:
#      chargelevel    count
# 0           0.00  7753189
# 1           0.01    15615
# 2           0.02     9230
# 3           0.03     8317
# 4           0.04     4253
# ..           ...      ...
# 974        99.63      142
# 975        99.78    27040
# 976        99.91      114
# 977       100.00  6508634
# 978          NaN        0
#
# [979 rows x 2 columns]

# %%
chle2 = '''
SELECT *
FROM scooters
WHERE chargelevel ISNULL
'''

cl2 = pd.read_sql(chle2, con=engine)
cl2
# Out:
#             pubdatetime   latitude  longitude
# 0   2019-07-04 11:51:44  36.139446 -86.738546  \
# 1   2019-07-04 11:56:45  36.139498 -86.738519
# 2   2019-07-04 12:01:45  36.139429 -86.738546
# 3   2019-07-04 12:06:45  36.139459 -86.738556
# 4   2019-07-04 12:11:45  36.139494 -86.738528
# ..                  ...        ...        ...
# 765 2019-06-16 00:30:39  36.158802 -86.780615
# 766 2019-06-16 17:06:20  36.158367 -86.799032
# 767 2019-06-16 17:11:20  36.158389 -86.799028
# 768 2019-06-23 20:22:34  36.166099 -86.782172
# 769 2019-06-23 20:27:34  36.165948 -86.782225
#
#                                            sumdid sumdtype chargelevel
# 0    Powered-2651de71-6602-3b70-5d9b-990dc39b34b3  Powered        None  \
# 1    Powered-2651de71-6602-3b70-5d9b-990dc39b34b3  Powered        None
# 2    Powered-2651de71-6602-3b70-5d9b-990dc39b34b3  Powered        None
# 3    Powered-2651de71-6602-3b70-5d9b-990dc39b34b3  Powered        None
# 4    Powered-2651de71-6602-3b70-5d9b-990dc39b34b3  Powered        None
# ..                                            ...      ...         ...
# 765  Powered-751e19ec-b697-a51f-04ea-0bf9a2e125c9  Powered        None
# 766  Powered-41d70d7d-7a93-d2b3-4346-9d3e9c9cd06d  Powered        None
# 767  Powered-41d70d7d-7a93-d2b3-4346-9d3e9c9cd06d  Powered        None
# 768  Powered-2923f3cd-568f-b703-49e9-4da763a1ba71  Powered        None
# 769  Powered-2923f3cd-568f-b703-49e9-4da763a1ba71  Powered        None
#
#     sumdgroup  costpermin companyname
# 0     Scooter        0.15        Bolt
# 1     Scooter        0.15        Bolt
# 2     Scooter        0.15        Bolt
# 3     Scooter        0.15        Bolt
# 4     Scooter        0.15        Bolt
# ..        ...         ...         ...
# 765   Scooter        0.15        Bolt
# 766   Scooter        0.15        Bolt
# 767   Scooter        0.15        Bolt
# 768   Scooter        0.15        Bolt
# 769   Scooter        0.15        Bolt
#
# [770 rows x 9 columns]

# %% [markdown]
# ### the curious case of Powered2460

# %%
further = '''
SELECT MAX(tripdistance)
FROM trips
'''

f = pd.read_sql(further, con=engine)
f['feet'] = f['max'].astype('int64')
f['miles'] = f['feet']/5280
f
# Out:
#             max      feet        miles
# 0  3.188448e+07  31884482  6038.727652

# %%
further2 = '''
SELECT *
FROM trips
WHERE tripdistance IN 
        (SELECT MAX(tripdistance)
        FROM trips)
'''

f2 = pd.read_sql(further2, con=engine)
f2
# Out:
#          pubtimestamp companyname triprecordnum       sumdid  tripduration
# 0 2019-07-05 01:18:52      Gotcha          GOT9  Powered2460           9.0  \
#
#    tripdistance   startdate starttime     enddate   endtime  startlatitude
# 0  3.188448e+07  2019-07-05  01:18:56  2019-07-05  01:27:56       36.16338  \
#
#    startlongitude  endlatitude  endlongitude
# 0      -86.780142     36.16628    -86.778127  \
#
#                                  triproute               create_dt
# 0  [('0', '0'), ('36.16628', '-86.77813')] 2019-07-06 07:13:12.210

# %%
wtf = '''
SELECT *
FROM scooters
WHERE sumdid = 'Powered2460'
'''

wtaf = pd.read_sql(wtf, con=engine)
wtaf
# Out:
#                   pubdatetime   latitude  longitude       sumdid sumdtype
# 0     2019-05-28 20:49:21.873  34.414480 -81.705614  Powered2460  Powered  \
# 1     2019-05-28 20:54:22.140  34.414278 -81.705785  Powered2460  Powered
# 2     2019-05-28 20:59:22.537  34.414278 -81.705785  Powered2460  Powered
# 3     2019-05-28 21:04:22.753  34.414278 -81.705785  Powered2460  Powered
# 4     2019-05-28 21:09:22.817  34.414278 -81.705785  Powered2460  Powered
# ...                       ...        ...        ...          ...      ...
# 17812 2019-07-31 23:39:15.250  33.792197 -84.402437  Powered2460  Powered
# 17813 2019-07-31 23:44:15.267  33.792197 -84.402437  Powered2460  Powered
# 17814 2019-07-31 23:49:15.433  33.792197 -84.402437  Powered2460  Powered
# 17815 2019-07-31 23:54:15.587  33.792197 -84.402437  Powered2460  Powered
# 17816 2019-07-31 23:59:15.753  33.792197 -84.402437  Powered2460  Powered
#
#        chargelevel sumdgroup  costpermin companyname
# 0             44.0   Scooter        0.15      Gotcha
# 1             42.0   Scooter        0.15      Gotcha
# 2             42.0   Scooter        0.15      Gotcha
# 3             42.0   Scooter        0.15      Gotcha
# 4             42.0   Scooter        0.15      Gotcha
# ...            ...       ...         ...         ...
# 17812         46.0   Scooter        0.15      Gotcha
# 17813         46.0   Scooter        0.15      Gotcha
# 17814         46.0   Scooter        0.15      Gotcha
# 17815         46.0   Scooter        0.15      Gotcha
# 17816         46.0   Scooter        0.15      Gotcha
#
# [17817 rows x 9 columns]

# %%
p2460 = '''
SELECT *
FROM trips
WHERE sumdid = 'Powered2460'
'''

p2460a = pd.read_sql(p2460, con=engine)
p2460a
# Out:
#           pubtimestamp companyname triprecordnum       sumdid  tripduration
# 0  2019-06-08 03:18:46      Gotcha         GOT23  Powered2460           3.0  \
# 1  2019-06-08 22:24:51      Gotcha        GOT163  Powered2460           9.0
# 2  2019-06-14 01:26:19      Gotcha         GOT11  Powered2460          19.0
# 3  2019-07-06 19:37:20      Gotcha        GOT108  Powered2460          12.0
# 4  2019-07-06 19:37:20      Gotcha        GOT109  Powered2460          12.0
# 5  2019-07-06 18:46:23      Gotcha        GOT101  Powered2460          11.0
# 6  2019-06-04 01:09:38      Gotcha         GOT13  Powered2460          15.0
# 20               [('36.15041', '-86.79569000000001')] 2019-06-27 06:57:50.287
# 21               [('36.15041', '-86.79569000000001')] 2019-06-27 06:57:50.507
# 22  [('36.15182', '-86.78024'), ('36.1519500000000... 2019-07-07 07:11:48.767
# 23  [('36.15182', '-86.78024'), ('36.1519500000000... 2019-07-07 07:11:47.637

# %%
further3 = '''
'''

# %% [markdown]
#     - What values are there in the sumdgroup column? Are there any that are not of interest for this project?

# %%
samedi = '''
SELECT DISTINCT sumdgroup
FROM scooters'''

dimanche = pd.read_sql(samedi, con=engine)
dimanche
# Out:
#   sumdgroup
# 0   bicycle
# 1   scooter
# 2   Scooter

# %% [markdown]
# ### outliers

# %%
outliers = '''
SELECT *
FROM trips
WHERE (tripdistance <= 1 AND tripduration > 5) 
    OR (tripdistance >52800 AND tripduration > 120)
ORDER BY sumdid DESC
'''

out1 = pd.read_sql(outliers, con=engine)
out1
# Out:
#                  pubtimestamp    companyname triprecordnum
# 0     2019-06-08 00:51:28.333           Lime         LIM95  \
# 1     2019-05-22 16:49:04.860           Lime         LIM64
# 2     2019-05-22 05:48:58.827           Lime        LIM824
# 3     2019-06-20 18:53:25.820           Lime        LIM759
# 4     2019-05-19 03:11:39.500           Bird       BRD7717
# ...                       ...            ...           ...
# 32498 2019-06-21 01:59:01.000  Bolt Mobility      BOL00064
# 32499 2019-06-22 09:55:11.000  Bolt Mobility      BOL00145
# 32500 2019-06-04 18:59:56.000  Bolt Mobility      BOL00171
# 32501 2019-05-26 17:46:49.000  Bolt Mobility      BOL00770
# 32502 2019-07-03 02:54:42.000  Bolt Mobility      BOL00042
#
#                                              sumdid  tripduration
# 0                             StandardLIRPOZ7X3ZVGO      5.133333  \
# 1                              PoweredZZNTWU4QI7MLI     87.916667
# 2                              PoweredZZNTWU4QI7MLI     87.916667
# 3                              PoweredZZNTWU4QI7MLI     27.066667
# 4                                      PoweredZZFGD      7.000000
# ...                                             ...           ...
# 32498  Powered-079ce993-98bd-417a-acfe-76e2861ebf9b     48.000000
# 32499  Powered-05fedb39-a00f-a5e0-2219-8c3c7dd1b80e   8532.000000
# 32500  Powered-058d0498-dac4-437f-5a45-c951da4040a2     21.000000
# 32501  Powered-0479bb84-afbd-0426-f1c4-df628542a88c     44.000000
# 32502  Powered-046201fb-6532-1f37-6334-3612fb1e61f7   6279.000000
#
#        tripdistance   startdate        starttime     enddate          endtime
# 0              0.00  2019-06-08         00:17:00  2019-06-08         00:22:08  \
# 1              0.00  2019-05-22         03:43:05  2019-05-22         05:11:00
# 2              0.00  2019-05-22         03:43:05  2019-05-22         05:11:00
# 3              0.00  2019-06-20         17:28:13  2019-06-20         17:55:17
# 4              0.00  2019-05-19  03:06:21.876666  2019-05-19  03:13:05.540000
# ...             ...         ...              ...         ...              ...
# 32498          0.00  2019-06-21         01:56:10  2019-06-21         01:56:58
# 32499      62611.55  2019-06-22         07:32:04  2019-06-22         09:54:16
# 32500          0.00  2019-06-04         18:59:02  2019-06-04         18:59:23
# 32501          0.00  2019-05-26         17:45:06  2019-05-26         17:45:50
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 6903                                                 []
# 6904  [('36.161594', '-86.776032'), ('36.161552', '-...
# 6905  [('36.155756', '-86.780320'), ('36.155637', '-...
# 6906  [('36.160596', '-86.815320'), ('36.160595', '-...
# 6907                                                 []
#
#                    create_dt
# 0    2019-07-17 06:23:59.217
# 1    2019-07-15 06:23:35.623
# 2    2019-07-11 06:21:38.050
# 3    2019-07-14 06:23:28.003
# 4    2019-07-13 06:22:59.467
# ...                      ...
# 6903 2019-05-26 05:59:38.637
# 6904 2019-06-16 06:08:31.417
# 6905 2019-06-02 06:01:24.130
# 6906 2019-06-30 06:16:36.670
# 6907 2019-07-07 06:21:09.460
#
# [6908 rows x 16 columns]

# %% [markdown]
# ### UNUSED Scooters

# %%
unused = '''
SELECT 
    COUNT(DISTINCT sumdid),
    companyname
FROM scooters
WHERE sumdid NOT IN 
        (SELECT DISTINCT sumdid
        FROM trips)
GROUP BY companyname
'''

uu = pd.read_sql(unused, con=engine)
uu
# Out:
#    count companyname
# 0    105        Bird
# 1      4        Bolt
# 2     58      Gotcha
# 3    761        Jump
# 4     73        Lime
# 5     12        Lyft
# 6     51        Spin

# %%
unused_one_half = '''
SELECT *
FROM scooters
WHERE sumdid NOT IN 
        (SELECT DISTINCT sumdid
        FROM trips)
LIMIT 5
'''

uuoh = pd.read_sql(unused_one_half, con=engine)
uuoh
# Out:
#               pubdatetime  latitude  longitude
# 0 2019-06-06 20:13:42.107  36.15954  -86.78228  \
# 1 2019-06-06 20:15:42.000  36.11820  -86.75290
# 2 2019-06-06 20:15:42.000  36.11990  -86.75310
# 3 2019-06-06 20:15:42.000  36.14750  -86.77280
# 4 2019-06-06 20:15:42.000  36.12000  -86.75340
#
#                                         sumdid sumdtype  chargelevel
# 0                         PoweredOJUAAK74GKEFJ  Powered         67.0  \
# 1  Powerede49876fd-f593-58f5-b131-0a0b8e11c2dd  Powered          0.0
# 2  Poweredc8e400ae-54a1-5133-8813-d9c2c441d4a4  Powered          1.0
# 3  Powerede7a22ef7-aaca-5d68-873a-c32e3a5a5626  Powered          1.0
# 4  Powereda699b0c6-39bf-54bc-a164-8bb323ab0122  Powered          2.0
#
#   sumdgroup  costpermin companyname
# 0   scooter        0.15        Lime
# 1   scooter        0.06        Jump
# 2   scooter        0.06        Jump
# 3   scooter        0.06        Jump
# 4   scooter        0.06        Jump

# %%
unused2 = '''
SELECT DISTINCT
        latitude,
        longitude
FROM scooters
WHERE sumdid NOT IN 
        (SELECT DISTINCT sumdid
        FROM trips)
LIMIT 5
'''

uu2 = pd.read_sql(unused2, con=engine)
uu2
# Out:
#     latitude  longitude
# 0  36.159395 -86.782917
# 1  36.157753 -86.745738
# 2  36.121339 -86.770438
# 3  36.150700 -86.802800
# 4  36.157780 -86.745544

# %%
unused3 = '''
SELECT DISTINCT
        pubdatetime
FROM scooters
WHERE sumdid NOT IN 
        (SELECT DISTINCT sumdid
        FROM trips)
ORDER BY pubdatetime
LIMIT 5
'''

uu3 = pd.read_sql(unused3, con=engine)
uu3
# Out:
#               pubdatetime
# 0 2019-05-01 00:01:41.247
# 1 2019-05-01 00:03:26.187
# 2 2019-05-01 00:03:31.633
# 3 2019-05-01 00:03:47.517
# 4 2019-05-01 00:03:58.807

# %% [markdown]
# bus_stops['geometry'] = bus_stops.apply(lambda x: Point((x.lng,
#                                                          x.lat)),
#                                         axis=1)
# bus_stops.head(3)
#
# ## For when it's time to plot this
